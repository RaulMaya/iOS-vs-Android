# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "archive/googleplaystore.csv"

# Read Google Play Store File and store into Pandas data frame
google_playstore = pd.read_csv(file_to_load)
google_playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
# Looking for all available categories in my DF
google_playstore["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
# Selecting only the Games from my Google App List
google_playstore_games = google_playstore.loc[google_playstore["Category"]=="GAME",:]
google_playstore_games
# Out:
#                                 App Category  Rating   Reviews Size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              Installs  Type Price Content Rating  \
# 1653     100,000,000+  Free     0   Everyone 10+
# 1654   1,000,000,000+  Free     0   Everyone 10+
# 1655     500,000,000+  Free     0       Everyone
# 1656      10,000,000+  Free     0       Everyone
# 1657      10,000,000+  Free     0       Everyone
# ...               ...   ...   ...            ...
# 10791         50,000+  Free     0       Everyone
# 10792      1,000,000+  Free     0       Everyone
# 10793        500,000+  Free     0           Teen
# 10803      1,000,000+  Free     0           Teen
# 10804        100,000+  Free     0           Teen
#
#                              Genres       Last Updated   Current Ver  \
# 1653   Adventure;Action & Adventure      July 31, 2018  2.347.225742
# 1654                         Arcade      July 12, 2018        1.90.0
# 1655                         Casual       July 5, 2018     1.129.0.2
# 1656                           Card     August 1, 2018       2.137.0
# 1657                         Casual      July 17, 2018        1.20.1
# ...                             ...                ...           ...
# 10791                          Word  December 18, 2013           1.0
# 10792                        Trivia       May 24, 2018        1.3.81
# 10793                          Card     August 1, 2018         2.6.6
# 10803                        Action     August 7, 2018       1.5.447
# 10804                          Card       May 22, 2018         4.1.3
#
#         Android Ver
# 1653     4.1 and up
# 1654     4.1 and up
# 1655     4.1 and up
# 1656     4.1 and up
# 1657   4.0.3 and up
# ...             ...
# 10791    2.2 and up
# 10792    4.0 and up
# 10793  4.0.3 and up
# 10803    4.0 and up
# 10804    2.3 and up
#
# [1144 rows x 13 columns]

# %%
# Columns Names
google_playstore_games.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Counting my data for cleaning
google_playstore_games.count()
# Out:
# App               1144
# Category          1144
# Rating            1097
# Reviews           1144
# Size              1144
# Installs          1144
# Type              1144
# Price             1144
# Content Rating    1144
# Genres            1144
# Last Updated      1144
# Current Ver       1144
# Android Ver       1144
# dtype: int64

# %%
# Dropping rows with missing information
google_playstore_games = google_playstore_games.dropna(how="any")
google_playstore_games
# Out:
#                                 App Category  Rating   Reviews Size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              Installs  Type Price Content Rating  \
# 1653     100,000,000+  Free     0   Everyone 10+
# 1654   1,000,000,000+  Free     0   Everyone 10+
# 1655     500,000,000+  Free     0       Everyone
# 1656      10,000,000+  Free     0       Everyone
# 1657      10,000,000+  Free     0       Everyone
# ...               ...   ...   ...            ...
# 10791         50,000+  Free     0       Everyone
# 10792      1,000,000+  Free     0       Everyone
# 10793        500,000+  Free     0           Teen
# 10803      1,000,000+  Free     0           Teen
# 10804        100,000+  Free     0           Teen
#
#                              Genres       Last Updated   Current Ver  \
# 1653   Adventure;Action & Adventure      July 31, 2018  2.347.225742
# 1654                         Arcade      July 12, 2018        1.90.0
# 1655                         Casual       July 5, 2018     1.129.0.2
# 1656                           Card     August 1, 2018       2.137.0
# 1657                         Casual      July 17, 2018        1.20.1
# ...                             ...                ...           ...
# 10791                          Word  December 18, 2013           1.0
# 10792                        Trivia       May 24, 2018        1.3.81
# 10793                          Card     August 1, 2018         2.6.6
# 10803                        Action     August 7, 2018       1.5.447
# 10804                          Card       May 22, 2018         4.1.3
#
#         Android Ver
# 1653     4.1 and up
# 1654     4.1 and up
# 1655     4.1 and up
# 1656     4.1 and up
# 1657   4.0.3 and up
# ...             ...
# 10791    2.2 and up
# 10792    4.0 and up
# 10793  4.0.3 and up
# 10803    4.0 and up
# 10804    2.3 and up
#
# [1097 rows x 13 columns]

# %%
google_playstore_games["Genres"].unique()
# Out:
# array(['Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
#        'Casual;Action & Adventure', 'Simulation', 'Adventure', 'Board',
#        'Trivia', 'Role Playing', 'Simulation;Education',
#        'Action;Action & Adventure', 'Casual;Brain Games',
#        'Simulation;Action & Adventure', 'Casino'], dtype=object)

# %%
google_playstore_games["Genres"] = google_playstore_games["Genres"].replace({"Action":"Action & Adventure",
                                                                            "Adventure":"Action & Adventure",
                                                                            "Adventure;Action & Adventure": "Action & Adventure",
                                                                            "Action;Action & Adventure":"Action & Adventure"})
google_playstore_games
# Out:
# <ipython-input-8-53406f1b3493>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_playstore_games["Genres"] = google_playstore_games["Genres"].replace({"Action":"Action & Adventure",
#                                 App Category  Rating   Reviews Size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              Installs  Type Price Content Rating              Genres  \
# 1653     100,000,000+  Free     0   Everyone 10+  Action & Adventure
# 1654   1,000,000,000+  Free     0   Everyone 10+              Arcade
# 1655     500,000,000+  Free     0       Everyone              Casual
# 1656      10,000,000+  Free     0       Everyone                Card
# 1657      10,000,000+  Free     0       Everyone              Casual
# ...               ...   ...   ...            ...                 ...
# 10791         50,000+  Free     0       Everyone                Word
# 10792      1,000,000+  Free     0       Everyone              Trivia
# 10793        500,000+  Free     0           Teen                Card
# 10803      1,000,000+  Free     0           Teen  Action & Adventure
# 10804        100,000+  Free     0           Teen                Card
#
#             Last Updated   Current Ver   Android Ver
# 1653       July 31, 2018  2.347.225742    4.1 and up
# 1654       July 12, 2018        1.90.0    4.1 and up
# 1655        July 5, 2018     1.129.0.2    4.1 and up
# 1656      August 1, 2018       2.137.0    4.1 and up
# 1657       July 17, 2018        1.20.1  4.0.3 and up
# ...                  ...           ...           ...
# 10791  December 18, 2013           1.0    2.2 and up
# 10792       May 24, 2018        1.3.81    4.0 and up
# 10793     August 1, 2018         2.6.6  4.0.3 and up
# 10803     August 7, 2018       1.5.447    4.0 and up
# 10804       May 22, 2018         4.1.3    2.3 and up
#
# [1097 rows x 13 columns]

# %%
# Converting the string form of installs into interger
google_playstore_games["Installs"] = google_playstore_games["Installs"].str.replace('+', '')
google_playstore_games["Installs"] = google_playstore_games["Installs"].str.replace(',', '')
google_playstore_games["Installs"] = google_playstore_games["Installs"].astype(int)
google_playstore_games
# Out:
#                                 App Category  Rating   Reviews  Size  \
# 1842               Candy Crush Saga     GAME     4.4  22429716   74M
# 1729                   Temple Run 2     GAME     4.3   8118937   62M
# 1920                   Temple Run 2     GAME     4.3   8119154   62M
# 1751               Candy Crush Saga     GAME     4.4  22428456   74M
# 4041                   Temple Run 2     GAME     4.3   8116142   62M
# ...                             ...      ...     ...       ...   ...
# 3977               B-Grade Renegade     GAME     3.9        24   64M
# 10484  FJ Final Join , Circles Game     GAME     4.7        32   24M
# 9480               WIZARD Card Game     GAME     4.0        48  4.1M
# 5917                       Ra Ga Ba     GAME     5.0         2   20M
# 10697                       Mu.F.O.     GAME     5.0         2   16M
#
#         Installs  Type  Price Content Rating              Genres  \
# 1842   500000000  Free      0       Everyone              Casual
# 1729   500000000  Free      0       Everyone  Action & Adventure
# 1920   500000000  Free      0       Everyone  Action & Adventure
# 1751   500000000  Free      0       Everyone              Casual
# 4041   500000000  Free      0       Everyone  Action & Adventure
# ...          ...   ...    ...            ...                 ...
# 3977        1000  Paid  $1.99           Teen  Action & Adventure
# 10484       1000  Free      0           Teen              Arcade
# 9480        1000  Paid  $1.99       Everyone                Card
# 5917           1  Paid  $1.49       Everyone              Arcade
# 10697          1  Paid  $0.99       Everyone              Arcade
#
#             Last Updated Current Ver Android Ver
# 1842        July 5, 2018   1.129.0.2  4.1 and up
# 1729        July 5, 2018      1.49.1  4.0 and up
# 1920        July 5, 2018      1.49.1  4.0 and up
# 1751        July 5, 2018   1.129.0.2  4.1 and up
# 4041        July 5, 2018      1.49.1  4.0 and up
# ...                  ...         ...         ...
# 3977    October 17, 2017      0.8.17  3.2 and up
# 10484      July 11, 2018        0.24  4.3 and up
# 9480   December 15, 2014  1.0.141215  2.1 and up
# 5917    February 8, 2017       1.0.4  2.3 and up
# 10697      March 3, 2017         1.0  2.3 and up
#
# [1097 rows x 13 columns]

# %%
# Looking for the most installed games
google_playstore_games=google_playstore_games.sort_values(by=["Installs"], ascending = False)
google_playstore_games.head(20)
# Out:
#                    App Category  Rating   Reviews                Size  \
# 1700    Subway Surfers     GAME     4.5  27723193                 76M
# 1750    Subway Surfers     GAME     4.5  27724094                 76M
# 3896    Subway Surfers     GAME     4.5  27711703                 76M
# 1872    Subway Surfers     GAME     4.5  27725352                 76M
# 1917    Subway Surfers     GAME     4.5  27725352                 76M
# 1654    Subway Surfers     GAME     4.5  27722264                 76M
# 1869  Candy Crush Saga     GAME     4.4  22430188                 74M
# 1729      Temple Run 2     GAME     4.3   8118937                 62M
# 1722    My Talking Tom     GAME     4.5  14891223  Varies with device
# 1661      Temple Run 2     GAME     4.3   8118609                 62M
# 1662               Pou     GAME     4.3  10485308                 24M
# 1655  Candy Crush Saga     GAME     4.4  22426677                 74M
# 1842  Candy Crush Saga     GAME     4.4  22429716                 74M
# 1886      Temple Run 2     GAME     4.3   8119151                 62M
# 1908    My Talking Tom     GAME     4.5  14892469  Varies with device
# 1705  Candy Crush Saga     GAME     4.4  22428456                 74M
# 1920      Temple Run 2     GAME     4.3   8119154                 62M
# 1751  Candy Crush Saga     GAME     4.4  22428456                 74M
# 4041      Temple Run 2     GAME     4.3   8116142                 62M
# 1966  Candy Crush Saga     GAME     4.4  22430188                 74M
#
#         Installs  Type Price Content Rating              Genres  \
# 1700  1000000000  Free     0   Everyone 10+              Arcade
# 1750  1000000000  Free     0   Everyone 10+              Arcade
# 3896  1000000000  Free     0   Everyone 10+              Arcade
# 1872  1000000000  Free     0   Everyone 10+              Arcade
# 1917  1000000000  Free     0   Everyone 10+              Arcade
# 1654  1000000000  Free     0   Everyone 10+              Arcade
# 1869   500000000  Free     0       Everyone              Casual
# 1729   500000000  Free     0       Everyone  Action & Adventure
# 1722   500000000  Free     0       Everyone              Casual
# 1661   500000000  Free     0       Everyone  Action & Adventure
# 1662   500000000  Free     0       Everyone              Casual
# 1655   500000000  Free     0       Everyone              Casual
# 1842   500000000  Free     0       Everyone              Casual
# 1886   500000000  Free     0       Everyone  Action & Adventure
# 1908   500000000  Free     0       Everyone              Casual
# 1705   500000000  Free     0       Everyone              Casual
# 1920   500000000  Free     0       Everyone  Action & Adventure
# 1751   500000000  Free     0       Everyone              Casual
# 4041   500000000  Free     0       Everyone  Action & Adventure
# 1966   500000000  Free     0       Everyone              Casual
#
#        Last Updated Current Ver Android Ver
# 1700  July 12, 2018      1.90.0  4.1 and up
# 1750  July 12, 2018      1.90.0  4.1 and up
# 3896  July 12, 2018      1.90.0  4.1 and up
# 1872  July 12, 2018      1.90.0  4.1 and up
# 1917  July 12, 2018      1.90.0  4.1 and up
# 1654  July 12, 2018      1.90.0  4.1 and up
# 1869   July 5, 2018   1.129.0.2  4.1 and up
# 1729   July 5, 2018      1.49.1  4.0 and up
# 1722  July 19, 2018   4.8.0.132  4.1 and up
# 1661   July 5, 2018      1.49.1  4.0 and up
# 1662   May 25, 2018      1.4.77  4.0 and up
# 1655   July 5, 2018   1.129.0.2  4.1 and up
# 1842   July 5, 2018   1.129.0.2  4.1 and up
# 1886   July 5, 2018      1.49.1  4.0 and up
# 1908  July 19, 2018   4.8.0.132  4.1 and up
# 1705   July 5, 2018   1.129.0.2  4.1 and up
# 1920   July 5, 2018      1.49.1  4.0 and up
# 1751   July 5, 2018   1.129.0.2  4.1 and up
# 4041   July 5, 2018      1.49.1  4.0 and up
# 1966   July 5, 2018   1.129.0.2  4.1 and up

# %%
# The Top 10 most installed games
google_playstore_games_grouped = google_playstore_games.groupby("App")
max_google_playstore_games = google_playstore_games_grouped.max()
most_installed_games = max_google_playstore_games.sort_values(by=["Installs"], ascending = False)
most_installed_games.head(10)
# Out:
#                                      Category  Rating   Reviews  \
# App
# Subway Surfers                           GAME     4.5  27725352
# Candy Crush Saga                         GAME     4.4  22430188
# Temple Run 2                             GAME     4.3   8119154
# Pou                                      GAME     4.3  10486018
# My Talking Tom                           GAME     4.5  14892469
# PAC-MAN                                  GAME     4.2    685981
# Asphalt 8: Airborne                      GAME     4.5   8389714
# Lep's World 2 🍀🍀                         GAME     4.3    798522
# Jetpack Joyride                          GAME     4.4   4638163
# Ant Smasher by Best Cool & Fun Games     GAME     4.2   1185148
#
#                                                     Size    Installs  Type  \
# App
# Subway Surfers                                       76M  1000000000  Free
# Candy Crush Saga                                     74M   500000000  Free
# Temple Run 2                                         62M   500000000  Free
# Pou                                                  24M   500000000  Free
# My Talking Tom                        Varies with device   500000000  Free
# PAC-MAN                                              37M   100000000  Free
# Asphalt 8: Airborne                                  92M   100000000  Free
# Lep's World 2 🍀🍀                                     57M   100000000  Free
# Jetpack Joyride                                      96M   100000000  Free
# Ant Smasher by Best Cool & Fun Games                 29M   100000000  Free
#
#                                      Price Content Rating              Genres  \
# App
# Subway Surfers                           0   Everyone 10+              Arcade
# Candy Crush Saga                         0       Everyone              Casual
# Temple Run 2                             0       Everyone  Action & Adventure
# Pou                                      0       Everyone              Casual
# My Talking Tom                           0       Everyone              Casual
# PAC-MAN                                  0       Everyone              Arcade
# Asphalt 8: Airborne                      0           Teen              Racing
# Lep's World 2 🍀🍀                         0   Everyone 10+              Arcade
# Jetpack Joyride                          0   Everyone 10+              Arcade
# Ant Smasher by Best Cool & Fun Games     0       Everyone              Arcade
#
#                                         Last Updated Current Ver   Android Ver
# App
# Subway Surfers                         July 12, 2018      1.90.0    4.1 and up
# Candy Crush Saga                        July 5, 2018   1.129.0.2    4.1 and up
# Temple Run 2                            July 5, 2018      1.49.1    4.0 and up
# Pou                                     May 25, 2018      1.4.77    4.0 and up
# My Talking Tom                         July 19, 2018   4.8.0.132    4.1 and up
# PAC-MAN                                 May 15, 2018       6.6.3    4.1 and up
# Asphalt 8: Airborne                     July 4, 2018      3.7.1a  4.0.3 and up
# Lep's World 2 🍀🍀                        June 7, 2018     1.9.8.0    4.1 and up
# Jetpack Joyride                        July 19, 2018     1.10.12    4.1 and up
# Ant Smasher by Best Cool & Fun Games  August 1, 2018        9.55  4.0.3 and up

# %%
google_playstore_games_grouped_by_genres = google_playstore_games.groupby("Genres")
mean_google_playstore_games = google_playstore_games_grouped_by_genres.mean()
most_installed_games_by_genre = mean_google_playstore_games.sort_values(by=["Installs"], ascending = False)
most_installed_games_by_genre
# Out:
#                                  Rating      Installs
# Genres
# Casual                         4.457778  1.544222e+08
# Casual;Action & Adventure      4.500000  1.000000e+08
# Sports                         4.535714  7.971429e+07
# Arcade                         4.304348  5.182163e+07
# Casual;Pretend Play            4.200000  5.000000e+07
# Strategy                       4.395833  4.822083e+07
# Puzzle                         4.526190  2.831429e+07
# Action & Adventure             4.271071  2.340258e+07
# Racing                         4.173118  2.150802e+07
# Simulation                     4.354545  1.828182e+07
# Music                          4.214286  1.524381e+07
# Casual;Creativity              4.100000  1.000000e+07
# Casual;Brain Games             4.400000  1.000000e+07
# Simulation;Action & Adventure  4.700000  1.000000e+07
# Word                           4.410714  9.613304e+06
# Role Playing                   4.400000  7.131250e+06
# Trivia                         4.039286  4.589361e+06
# Board                          4.292683  4.076268e+06
# Card                           4.086667  3.618322e+06
# Casino                         4.286486  3.520543e+06
# Simulation;Education           4.500000  1.000000e+05
